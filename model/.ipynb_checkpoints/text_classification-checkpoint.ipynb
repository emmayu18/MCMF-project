# %% [markdown]
# # MCMF Text Classification

# %% [markdown]
# ## Load Packages

# %%
# import libraries
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# text pre-processing
import re, string
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import SnowballStemmer
from nltk.stem import PorterStemmer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
from collections import Counter
# nltk.download('punkt')
# nltk.download('averaged_perceptron_tagger')
# nltk.download('wordnet')
# nltk.download('stopwords')
# nltk.download('omw-1.4')

# model-building
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier, StackingClassifier
from sklearn.svm import LinearSVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, roc_auc_score, hamming_loss

# LSTM
# import tensorflow as tf
# from tensorflow.keras.preprocessing.text import Tokenizer
# from tensorflow.keras.preprocessing.sequence import pad_sequences
# from tensorflow.keras.callbacks import EarlyStopping
# from sklearn.preprocessing import LabelEncoder
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import LSTM, Dense, Embedding, Dropout, SpatialDropout1D
# from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ## Load Data

# %%
# cleaned data from R
dat = pd.read_csv("../data/wrangle/text_classify.csv")
dat = dat.drop("index", axis = 1).rename(columns = {"Unnamed: 0": "index"})
dat
# Out:
#        index                                       program_name  \
# 0          1                                       STEM Academy
# 1          2                  CHANCE - Digital Scholars Program
# 2          3                         Future Leaders in Business
# 3          4                          Divas Code Virtual Meetup
# 4          5                                 Divas Office Hours
# ...      ...                                                ...
# 20221  20222                             Spring Break STEM Camp
# 20222  20223  The Art Institute of Chicago Ryan Learning Cen...
# 20223  20224                           ILA Match Apprenticeship
# 20224  20225                             Student WEB CORPS 2023
# 20225  20226                          Summer Coding at UChicago
#
#                                              description  \
# 0      <p><strong>The UIC – CHANCE STEM Academy Progr...
# 1      <p>This <strong>5-Week Virtual Summer Program<...
# 2      <p>The <strong>UIC Future Leaders in Business ...
# 3      <p>Our weekly virtual office hours are an to g...
# 4      <p>Our weekly virtual office hours are an to g...
# ...                                                  ...
# 20221  <p>Project Exploration creates transformative ...
# 20222  The Art Exchange in the Ryan Learning Center (...
# 20223  <p>Are you between the ages of 12-14 and have ...
# 20224  <p>Student WEB CORPS is a 6-week program, from...
# 20225  <p>Hey there, students!</p><p>Are you ready to...
#
#                           category
# 0      Professional Skill Building
# 1      Professional Skill Building
# 2      Professional Skill Building
# 3      Professional Skill Building
# 4      Professional Skill Building
# ...                            ...
# 20221                    Academics
# 20222             Leisure and Arts
# 20223             Leisure and Arts
# 20224  Professional Skill Building
# 20225  Professional Skill Building
#
# [20226 rows x 4 columns]

# %%
plt.bar(x.index, x)
plt.xlabel('Categories')
plt.tick_params(axis='x', labelsize=7.5)
plt.ylabel('Count')
plt.show()

# %% [markdown]
# There is an imbalance in the outcome variable so I will be stratifying the test/train data by category and using stratified K-fold during grid search. I will also be using the macro averaging method for my performance metrics.

# %% [markdown]
# ## Text Pre-Processing

# %%
# text conversion
def clean_text(text):
    # lower strings
    text = text.lower()
    # strip
    text = text.strip()
    # remove html tags
    text = re.sub("<.*?>", " ", text)
    # remove html entities
    text = re.sub("&.*?;", " ", text)
    # remove URL links
    text = re.sub("https?:\/\/(www\.)?[-a-zA-Z0-9@:%._\+~#=]{1,256}\.[a-zA-Z0-9()]{1,6}\b([-a-zA-Z0-9()@:%_\+.~#?&//=]*)", " ", text)
    text = re.sub("www(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", " ", text)
    # remove punctuation, numbers, and special characters
    text = re.sub("[^a-zA-Z\\s]", " ", text)
    # remove all words with nchar <= 2
    text = re.sub(r'\b\w{1,2}\b', " ", text)
    # remove words that start with "zoom"
    text = re.sub("zoom\w+", " ", text)
    # remove words that start with "zoom"
    text = re.sub("accessibility\w+", " ", text)
    # all spaces to singlespace 
    text = re.sub('\s+', ' ', text)  
    return text

# stop word removal
custom_stopwords = stopwords.words('english')
custom_stopwords.extend(["event", "chicago", "please", "program", "camp", "tbd", "tba","internship", "illinois", 
                         "zoom","january", "february", "march", "april", "may", "june", "july", "august", 
                         "september", "october", "november", "december", "monday", "tuesday", "wednesday", "thursday",
                         "friday", "saturday", "sunday", "sun", "mon", "tue", "wed", "thu", "fri", "sat"])
custom_stopwords = [re.sub("[^a-zA-Z\\s]", "", text) for text in custom_stopwords]

def remove_stopword(string):
    a = [i for i in string.split() if i not in custom_stopwords]
    return ' '.join(a)

# stemming
ps = PorterStemmer()

def stemmer(string):
    tokens = word_tokenize(string)
    a = [ps.stem(word) for word in tokens]
    return " ".join(a)

# final function
def finalpreprocess(string):
    return remove_stopword(stemmer(remove_stopword(clean_text(string))))
dat['clean_text'] = dat['description'].apply(lambda x: finalpreprocess(x))

# %%
# remove frequent words and rare words
cnt = Counter()
for text in dat["clean_text"].values:
    for word in text.split():
        cnt[word] += 1

freq_words = set([w for (w, wc) in cnt.most_common(30)])
def remove_freqwords(text):
    return " ".join([word for word in str(text).split() if word not in freq_words])
dat['clean_text'] = dat['clean_text'].apply(lambda x: remove_freqwords(x))

rare_words = set([key for key, value in cnt.items() if value == 1])
def remove_rarewords(text):
    return " ".join([word for word in str(text).split() if word not in rare_words])
dat['clean_text'] = dat['clean_text'].apply(lambda x: remove_rarewords(x))

dat.head()
# Out:
#    index                       program_name  \
# 0      1                       STEM Academy
# 1      2  CHANCE - Digital Scholars Program
# 2      3         Future Leaders in Business
# 3      4          Divas Code Virtual Meetup
# 4      5                 Divas Office Hours
#
#                                          description  \
# 0  <p><strong>The UIC – CHANCE STEM Academy Progr...
# 1  <p>This <strong>5-Week Virtual Summer Program<...
# 2  <p>The <strong>UIC Future Leaders in Business ...
# 3  <p>Our weekly virtual office hours are an to g...
# 4  <p>Our weekly virtual office hours are an to g...
#
#                       category  \
# 0  Professional Skill Building
# 1  Professional Skill Building
# 2  Professional Skill Building
# 3  Professional Skill Building
# 4  Professional Skill Building
#
#                                           clean_text
# 0  uic chanc stem academi five week academ intens...
# 1  week virtual summer afford high school sophomo...
# 2  uic futur leader busi free summer partnership ...
# 3  weekli virtual offic hour get feedback support...
# 4  weekli virtual offic hour get feedback support...

# %% [markdown]
# ## Split Data

# %%
# split predictor and outcome variables
y = dat["category"]
X = dat["clean_text"]

# split training and testing data
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    test_size=0.2, 
                                                    stratify = y, 
                                                    shuffle=True,
                                                    random_state = 42)

# %% [markdown]
# ## TF-IDF

# %%
tfidf_vectorizer = TfidfVectorizer(use_idf=True, max_features = 5000)
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train) 
X_test_tfidf = tfidf_vectorizer.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
lr = LogisticRegression()
lr_grid = {"C": [10, 1.0, 0.1, 0.01]}

lr_grid_search = GridSearchCV(estimator = lr, 
                              param_grid = lr_grid, 
                              scoring = "accuracy", 
                              cv = StratifiedKFold(5),
                              verbose = 2)
lr_grid_search = lr_grid_search.fit(X_train_tfidf, y_train)
lr.set_params(**lr_grid_search.best_params_)
print("Best parameters: ", lr_grid_search.best_params_)
print("Best score: ", lr_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END ...............................................C=10; total time=   1.3s
# [CV] END ...............................................C=10; total time=   1.5s
# [CV] END ...............................................C=10; total time=   1.3s
# [CV] END ...............................................C=10; total time=   1.4s
# [CV] END ...............................................C=10; total time=   1.6s
# [CV] END ..............................................C=1.0; total time=   1.7s
# [CV] END ..............................................C=1.0; total time=   1.7s
# [CV] END ..............................................C=1.0; total time=   1.7s
# [CV] END ..............................................C=1.0; total time=   2.1s
# [CV] END ..............................................C=1.0; total time=   1.8s
# [CV] END ..............................................C=0.1; total time=   0.8s
# [CV] END ..............................................C=0.1; total time=   0.8s
# [CV] END ..............................................C=0.1; total time=   0.7s
# [CV] END ..............................................C=0.1; total time=   0.8s
# [CV] END ..............................................C=0.1; total time=   0.8s
# [CV] END .............................................C=0.01; total time=   0.3s
# [CV] END .............................................C=0.01; total time=   0.3s
# [CV] END .............................................C=0.01; total time=   0.3s
# [CV] END .............................................C=0.01; total time=   2.1s
# [CV] END .............................................C=0.01; total time=   0.3s
# Best parameters:  {'C': 10}
# Best score:  0.8695920889987638

# %% [markdown]
# ## Multinomal Naive-Bayes

# %%
nb = MultinomialNB()
nb_grid = {"alpha": [0.0001, 0.001, 0.1, 1, 10, 100]}

nb_grid_search = GridSearchCV(estimator = nb, 
                              param_grid = nb_grid, 
                              scoring = "accuracy", 
                              cv = StratifiedKFold(),
                              verbose = 2)
nb_grid_search = nb_grid_search.fit(X_train_tfidf, y_train)
nb.set_params(**nb_grid_search.best_params_)
print("Best parameters: ", nb_grid_search.best_params_)
print("Best score: ", nb_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.0s
# [CV] END .......................................alpha=0.0001; total time=   0.1s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ........................................alpha=0.001; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.0s
# [CV] END ..........................................alpha=0.1; total time=   0.1s
# [CV] END ..........................................alpha=0.1; total time=   0.1s
# [CV] END ............................................alpha=1; total time=   0.1s
# [CV] END ............................................alpha=1; total time=   0.1s
# [CV] END ............................................alpha=1; total time=   0.1s
# [CV] END ............................................alpha=1; total time=   0.1s
# [CV] END ............................................alpha=1; total time=   0.1s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.0s
# [CV] END ...........................................alpha=10; total time=   0.1s
# [CV] END ...........................................alpha=10; total time=   0.1s
# [CV] END ...........................................alpha=10; total time=   0.1s
# [CV] END ..........................................alpha=100; total time=   0.1s
# [CV] END ..........................................alpha=100; total time=   0.1s
# [CV] END ..........................................alpha=100; total time=   0.0s
# [CV] END ..........................................alpha=100; total time=   0.1s
# [CV] END ..........................................alpha=100; total time=   0.1s
# Best parameters:  {'alpha': 0.001}
# Best score:  0.8299752781211372

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier()
rf_grid = {'n_estimators': [100, 150, 200],
           'max_depth': [200, None]}

#0.8527 {'max_depth': None, 'n_estimators': 200}

rf_grid_search = GridSearchCV(estimator = rf, 
                              param_grid = rf_grid, 
                              scoring = "accuracy", 
                              cv = StratifiedKFold(5),
                              verbose = 2)
rf_grid_search = rf_grid_search.fit(X_train_tfidf, y_train)
rf.set_params(**rf_grid_search.best_params_)
print("Best parameters: ", rf_grid_search.best_params_)
print("Best score: ", rf_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [CV] END ....................max_depth=200, n_estimators=100; total time=  16.2s
# [CV] END ....................max_depth=200, n_estimators=100; total time=  16.8s
# [CV] END ....................max_depth=200, n_estimators=100; total time=  16.9s
# [CV] END ....................max_depth=200, n_estimators=100; total time=  16.1s
# [CV] END ....................max_depth=200, n_estimators=100; total time=  16.4s
# [CV] END ....................max_depth=200, n_estimators=150; total time=  24.9s
# [CV] END ....................max_depth=200, n_estimators=150; total time=  24.3s
# [CV] END ....................max_depth=200, n_estimators=150; total time=  23.8s
# [CV] END ....................max_depth=200, n_estimators=150; total time=  24.1s
# [CV] END ....................max_depth=200, n_estimators=150; total time=  23.7s
# [CV] END ....................max_depth=200, n_estimators=200; total time=  31.0s
# [CV] END ....................max_depth=200, n_estimators=200; total time=  31.6s
# [CV] END ....................max_depth=200, n_estimators=200; total time=  32.8s
# [CV] END ....................max_depth=200, n_estimators=200; total time=  32.7s
# [CV] END ....................max_depth=200, n_estimators=200; total time=  31.2s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  16.2s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  15.6s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  15.6s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  15.7s
# [CV] END ...................max_depth=None, n_estimators=100; total time=  15.3s
# [CV] END ...................max_depth=None, n_estimators=150; total time=  22.7s
# [CV] END ...................max_depth=None, n_estimators=150; total time=  24.0s
# [CV] END ...................max_depth=None, n_estimators=150; total time=  23.7s
# [CV] END ...................max_depth=None, n_estimators=150; total time=  23.9s
# [CV] END ...................max_depth=None, n_estimators=150; total time=  24.1s
# [CV] END ...................max_depth=None, n_estimators=200; total time=  31.0s
# [CV] END ...................max_depth=None, n_estimators=200; total time=  31.5s
# [CV] END ...................max_depth=None, n_estimators=200; total time=  30.5s
# [CV] END ...................max_depth=None, n_estimators=200; total time=  59.7s
# [CV] END ...................max_depth=None, n_estimators=200; total time=  48.2s
# Best parameters:  {'max_depth': None, 'n_estimators': 200}
# Best score:  0.8526576019777503

# %% [markdown]
# ## SVM

# %%
svm = LinearSVC()
svm_grid = {"C": [0.01, 0.1, 1, 10]}

svm_grid_search = GridSearchCV(estimator = svm, 
                               param_grid = svm_grid, 
                               scoring = "accuracy", 
                               cv = StratifiedKFold(),
                               verbose = 2)
svm_grid_search = svm_grid_search.fit(X_train_tfidf, y_train)
svm.set_params(**svm_grid_search.best_params_)
print("Best parameters: ", svm_grid_search.best_params_)
print("Best score: ", svm_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV] END .............................................C=0.01; total time=   0.2s
# [CV] END .............................................C=0.01; total time=   0.3s
# [CV] END .............................................C=0.01; total time=   0.2s
# [CV] END .............................................C=0.01; total time=   0.2s
# [CV] END .............................................C=0.01; total time=   0.2s
# [CV] END ..............................................C=0.1; total time=   0.2s
# [CV] END ..............................................C=0.1; total time=   0.2s
# [CV] END ..............................................C=0.1; total time=   0.3s
# [CV] END ..............................................C=0.1; total time=   0.2s
# [CV] END ..............................................C=0.1; total time=   0.2s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.4s
# [CV] END ................................................C=1; total time=   0.3s
# [CV] END ................................................C=1; total time=   0.3s
# [CV] END ...............................................C=10; total time=   2.4s
# [CV] END ...............................................C=10; total time=   2.5s
# [CV] END ...............................................C=10; total time=   2.3s
# [CV] END ...............................................C=10; total time=   1.3s
# [CV] END ...............................................C=10; total time=   1.4s
# Best parameters:  {'C': 1}
# Best score:  0.872991347342398

# %% [markdown]
# ## K-Nearest Neighbors

# %%
knn = KNeighborsClassifier()
knn_grid = {"n_neighbors": np.arange(1, 10, 2), "weights": ["uniform", "distance"]}

knn_grid_search = GridSearchCV(estimator = knn, 
                               param_grid = knn_grid, 
                               scoring = "accuracy", 
                               cv = StratifiedKFold(),
                               verbose = 2)
knn_grid_search = knn_grid_search.fit(X_train_tfidf, y_train)
knn.set_params(**knn_grid_search.best_params_)
print("Best parameters: ", knn_grid_search.best_params_)
print("Best score: ", knn_grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   2.1s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   1.6s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   1.7s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   1.6s
# [CV] END .....................n_neighbors=1, weights=uniform; total time=   1.7s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   1.5s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   1.5s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   1.5s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   1.5s
# [CV] END ....................n_neighbors=1, weights=distance; total time=   1.7s
# [CV] END .....................n_neighbors=3, weights=uniform; total time=   1.7s
# [CV] END .....................n_neighbors=3, weights=uniform; total time=   1.8s
# [CV] END .....................n_neighbors=3, weights=uniform; total time=   1.9s
# [CV] END .....................n_neighbors=3, weights=uniform; total time=   2.2s
# [CV] END .....................n_neighbors=3, weights=uniform; total time=   2.5s
# [CV] END ....................n_neighbors=3, weights=distance; total time=   2.0s
# [CV] END ....................n_neighbors=3, weights=distance; total time=   1.7s
# [CV] END ....................n_neighbors=3, weights=distance; total time=   1.9s
# [CV] END ....................n_neighbors=3, weights=distance; total time=   1.7s
# [CV] END ....................n_neighbors=3, weights=distance; total time=   1.7s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   2.0s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   2.5s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   2.1s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   2.3s
# [CV] END .....................n_neighbors=5, weights=uniform; total time=   2.6s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   2.1s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   2.1s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   2.1s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   2.3s
# [CV] END ....................n_neighbors=5, weights=distance; total time=   2.4s
# [CV] END .....................n_neighbors=7, weights=uniform; total time=   2.2s
# [CV] END .....................n_neighbors=7, weights=uniform; total time=   2.2s
# [CV] END .....................n_neighbors=7, weights=uniform; total time=   2.4s
# [CV] END .....................n_neighbors=7, weights=uniform; total time=   2.5s
# [CV] END .....................n_neighbors=7, weights=uniform; total time=   2.2s
# [CV] END ....................n_neighbors=7, weights=distance; total time=   2.0s
# [CV] END ....................n_neighbors=7, weights=distance; total time=   2.4s
# [CV] END ....................n_neighbors=7, weights=distance; total time=   2.4s
# [CV] END ....................n_neighbors=7, weights=distance; total time=   2.7s
# [CV] END ....................n_neighbors=7, weights=distance; total time=   2.3s
# [CV] END .....................n_neighbors=9, weights=uniform; total time=   2.4s
# [CV] END .....................n_neighbors=9, weights=uniform; total time=   2.1s
# [CV] END .....................n_neighbors=9, weights=uniform; total time=   2.4s
# [CV] END .....................n_neighbors=9, weights=uniform; total time=   2.1s
# [CV] END .....................n_neighbors=9, weights=uniform; total time=   2.2s
# [CV] END ....................n_neighbors=9, weights=distance; total time=   2.3s
# [CV] END ....................n_neighbors=9, weights=distance; total time=   2.2s
# [CV] END ....................n_neighbors=9, weights=distance; total time=   2.1s
# [CV] END ....................n_neighbors=9, weights=distance; total time=   2.2s
# [CV] END ....................n_neighbors=9, weights=distance; total time=   2.1s
# Best parameters:  {'n_neighbors': 1, 'weights': 'uniform'}
# Best score:  0.8121755253399259

# %% [markdown]
# ## Stacked Model

# %%
estimators = [('lr', lr),
              ('nb', nb),
              ('rf', rf),
              ('svm', svm),
              ('knn', knn)
             ]

stack = StackingClassifier(estimators = estimators,
                           final_estimator = LogisticRegression(),
                           cv = 5)

# %%
np.mean(cross_val_score(stack, X_train_tfidf, y_train, cv=5))
#0.8700 no removal
#0.8695 random removal

# %% [markdown]
# ## Test Model

# %% [markdown]
# The model with the highest average cross validated training score was the stacked model.

# %%
stack_fitted = stack.fit(X_train_tfidf, y_train)
y_pred_stack = stack_fitted.predict(X_test_tfidf)
y_pred_prob = stack_fitted.predict_proba(X_test_tfidf)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred_stack))
print("F1-score:", f1_score(y_test, y_pred_stack, average = "macro"))
print("Precision:", precision_score(y_test, y_pred_stack, average = 'macro'))
print("Recall:", recall_score(y_test, y_pred_stack, average = 'macro'))
print("ROC AUC", roc_auc_score(y_test, y_pred_prob, multi_class = 'ovo'))
print("Hamming loss:", hamming_loss(y_test, y_pred_stack))
# Out:
# Accuracy: 0.8828472565496787
# F1-score: 0.7273188000347653
# Precision: 0.794939199589645
# Recall: 0.6808597812921084
# ROC AUC 0.9448034522352265
# Hamming loss: 0.11715274345032131

# %% [markdown]
# ## Predict Unclassified Data

# %% [markdown]
# ### Multi-category observations from original data (taken out before training)

# %%
unclass_dat = pd.read_csv("../data/wrangle/unclassified_text.csv")
unclass_dat = unclass_dat.rename(columns = {"Unnamed: 0": "index"})
unclass_dat['clean_text'] = unclass_dat['description'].apply(lambda x: finalpreprocess(x))
unclass_dat
# Out:
#       index                                   program_name  \
# 0         1                              Hack the Pandemic
# 1         2                              Virtual Workshops
# 2         3  Art & Science Workshop Series:  Intro to Art!
# 3         4            The Science of Art Virtual Workshop
# 4         5            The Art of Science virtual workshop
# ...     ...                                            ...
# 1081   1082     Coach for Success - UIC Student Life Visit
# 1082   1083                      Coach for Success Program
# 1083   1084                        Code For Good Hackathon
# 1084   1085                        Global Partners Project
# 1085   1086                            Austin Spring Fling
#
#                                             description  leisure_arts_dum  \
# 0     <p>Student will engage in a social impact proj...                 0
# 1     <p>TechGirlz provides free, hands-on TechShopz...                 0
# 2     Join us for a series of virtual workshops on t...                 1
# 3     Join Shedd Aquarium Teen Learning Lab for a se...                 1
# 4     Join Shedd Aquarium Teen Learning Lab for a se...                 1
# ...                                                 ...               ...
# 1081  <p>Students will learn and explore many opport...                 1
# 1082  <p style="text-align: justify;">Coach for Succ...                 0
# 1083  <p>Attention technologists, developers, design...                 0
# 1084  <p>The WMP's Global Partners Project is a 5-we...                 0
# 1085  <p>We are hosting a Spring Fling kickback wher...                 1
#
#       academics_dum  community_service_dum  professional_skill_dum  \
# 0                 1                      1                       0
# 1                 1                      0                       1
# 2                 1                      0                       0
# 3                 1                      0                       0
# 4                 1                      0                       0
# ...             ...                    ...                     ...
# 1081              1                      0                       0
# 1082              1                      0                       1
# 1083              1                      0                       1
# 1084              0                      1                       1
# 1085              0                      0                       1
#
#                                              clean_text
# 0     student engag social impact project develop de...
# 1     techgirlz provid free hand techshopz tech work...
# 2     join seri virtual workshop connect art scienc ...
# 3     join shedd aquarium teen learn lab seri virtua...
# 4     join shedd aquarium teen learn lab seri virtua...
# ...                                                 ...
# 1081  student learn explor mani opportun student lif...
# 1082  coach success cf urban initi colleg career rea...
# 1083  attent technologist develop design data scient...
# 1084  wmp global partner project week cross cultur i...
# 1085  host spring fling kickback youth come enjoy fr...
#
# [1086 rows x 8 columns]

# %%
X_unclass = unclass_dat["clean_text"]
X_unclass_tfidf = tfidf_vectorizer.transform(X_unclass)

# %%
pred = stack_fitted.predict(X_unclass_tfidf)
results = pd.concat([unclass_dat[["program_name", 
                                  "academics_dum", 
                                  "leisure_arts_dum", 
                                  "community_service_dum", 
                                  "professional_skill_dum"]], 
                     pd.Series(pred)], axis = 1)
results = results.rename(columns = {"academics_dum": "Academics", 
                                    "leisure_arts_dum": "Leisure and Arts", 
                                    "community_service_dum": "Community Service", 
                                    "professional_skill_dum": "Professional Skill Building",
                                    0: "pred"})
results
# Out:
#                                        program_name  Academics  \
# 0                                 Hack the Pandemic          1
# 1                                 Virtual Workshops          1
# 2     Art & Science Workshop Series:  Intro to Art!          1
# 3               The Science of Art Virtual Workshop          1
# 4               The Art of Science virtual workshop          1
# ...                                             ...        ...
# 1081     Coach for Success - UIC Student Life Visit          1
# 1082                      Coach for Success Program          1
# 1083                        Code For Good Hackathon          1
# 1084                        Global Partners Project          0
# 1085                            Austin Spring Fling          0
#
#       Leisure and Arts  Community Service  Professional Skill Building  \
# 0                    0                  1                            0
# 1                    0                  0                            1
# 2                    1                  0                            0
# 3                    1                  0                            0
# 4                    1                  0                            0
# ...                ...                ...                          ...
# 1081                 1                  0                            0
# 1082                 0                  0                            1
# 1083                 0                  0                            1
# 1084                 0                  1                            1
# 1085                 1                  0                            1
#
#                              pred
# 0                Leisure and Arts
# 1     Professional Skill Building
# 2                Leisure and Arts
# 3                       Academics
# 4                       Academics
# ...                           ...
# 1081                    Academics
# 1082                    Academics
# 1083  Professional Skill Building
# 1084  Professional Skill Building
# 1085             Leisure and Arts
#
# [1086 rows x 6 columns]

# %%
# loop through observations and True if 
def correct(row):
    pred = row["pred"]
    if row[pred] == 1:
        return True
    else:
        return False

compare = results.apply(func = correct, axis = 1)
print("Number of correctly labeled observations:", np.sum(compare))
print("Proportion of correctly labeled observations:", np.sum(compare) / len(compare))
# Out:
# Number of correctly labeled observations: 993
# Proportion of correctly labeled observations: 0.914364640883978

# %% [markdown]
# ### Handmade Sample Data

# %%
description1 = "Come learn Python coding at the Chicago Public Library! We will be going over the basics of computer programming along with a fun activity of making a tic-tac-toe game using code."
description2 = "Origami, painting, paper mache, ceramics, drawing, we have it all! Join us for a weekend of hands-on crafts and acitivities. We are located in Rogers Park, Illinois. Make sure to bring your parent's signatures."
description3 = "Do you need volunteering hours? Cleveland Clinic is looking for students to give back to their community through many different opportunities. Whether you're interested in patient interaction or looking for a more behind the scenes work, we have all sorts of ways you can help! Contact us if you're interested."
description4 = "We are offering tutoring services to middle school and high school students who are looking for extra afterschool help. We have college student tutors who have experience in teaching math, english, science, and history. The cost is covered by the Chicago Charity Foundation! Contact us at 123-456-7890 or find us at www.tutoring.com."

sample_dat = pd.DataFrame({"description": [description1, description2, description3, description4],
                           "category": ["Professional Skill Building", "Leisure and Arts", "Community Service", "Academics"]})
sample_dat
# Out:
#                                          description  \
# 0  Come learn Python coding at the Chicago Public...
# 1  Origami, painting, paper mache, ceramics, draw...
# 2  Do you need volunteering hours? Cleveland Clin...
# 3  We are offering tutoring services to middle sc...
#
#                       category
# 0  Professional Skill Building
# 1             Leisure and Arts
# 2            Community Service
# 3                    Academics

# %%
sample_dat['clean_text'] = sample_dat['description'].apply(lambda x: finalpreprocess(x))
X_sample = sample_dat["clean_text"]
X_sample_tfidf = tfidf_vectorizer.transform(X_sample)

pred = stack_fitted.predict(X_sample_tfidf)
true = sample_dat['category']

sample_results = pd.concat([sample_dat['category'], pd.Series(pred)], axis = 1)
sample_results = sample_results.rename(columns = {"category": "true", 0: "predicted"})
sample_results
# Out:
#                           true                    predicted
# 0  Professional Skill Building  Professional Skill Building
# 1             Leisure and Arts             Leisure and Arts
# 2            Community Service             Leisure and Arts
# 3                    Academics                    Academics
